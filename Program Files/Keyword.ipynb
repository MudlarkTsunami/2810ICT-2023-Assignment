# %%
# Library Imports

import pandas as pd
from datetime import datetime

# NOTE!!! CODE REQUIRED TO RECIEVE INPUT VARIABLES  keyword, s_date, e_date

# TEST
#keyword = 'pool'
#s_date = '2019-01-19'
#e_date = '2019-02-19'

# %%
listings_df = pd.read_csv("Data/listings_dec18.csv")
calendar_df = pd.read_csv("Data/calendar_dec18.csv")
# Out:
# C:\Users\zhard\AppData\Local\Temp\ipykernel_23856\973654433.py:1: DtypeWarning: Columns (43,61,62,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   listings_df = pd.read_csv("Data/listings_dec18.csv")

# %%
# Description dataframe extraction 
check_attributes = ['id','summary','space','description']
listings_df = listings_df[check_attributes]

# Datframe Convertions

# date to datetime datatype
calendar_df['date'] = pd.to_datetime(calendar_df['date'])

# listing_id to id in calendar_df
calendar_df.rename(columns={'listing_id': 'id'}, inplace=True)

# calendar dataframe attribute drops
calendar_df = calendar_df.drop('available', axis=1)
calendar_df = calendar_df.drop('price', axis=1)

# %%
# Define Functions for Filtered Dataframe Creation

# Filtering by Keyword check
def keyword_filtered_listings(listings_df, keyword, check_attributes):
    # Function to check if keyword is in any specified column of a row
    def contains_keyword(row):
        for at in check_attributes:
            if keyword.lower() in str(row[at]).lower():
                return True 
        return False
    
    # Applying the function to filter the DataFrame and return the result
    return listings_df[listings_df.apply(contains_keyword, axis=1)]

# Filtering by dates
def date_filtered_listings(calendar_df,s_date, e_date):
    fdate_df = calendar_df[((calendar_df['date'] > s_date) & (calendar_df['date'] < e_date))]
    return fdate_df
    # Outputs data frame containing filtered listings

# %%
# Execute function
flist_df = keyword_filtered_listings(listings_df, keyword, check_attributes) 
fdate_df = date_filtered_listings(calendar_df,s_date, e_date)

# %%
# Merges both filtered dataframes based on listing id
f_df = pd.merge (flist_df, fdate_df, on='id')

# sort 
f_df = f_df.sort_values(by=['id'])

#Drop Duplicates
f_df = f_df.drop_duplicates(subset='id', keep='first')
f_df
# Out:
#               id                                            summary
# 0          20865  Hi! We are a married professional couple with ...  \
# 47         38073  Welcome to my sanctuary - a bright, comfortabl...
# 76         39348  Fully self-contained sunny studio apartment.  ...
# 111        67295  On major bus routes to City, Castle Hill, Rous...
# 138        73802  This is a fabulous contemporary villa in perfe...
# ...          ...                                                ...
# 188296  30577002  Double bedroom with en-suite bathroom in our f...
# 188331  30577731  Very convenient location! Wolli Creek 50 meter...
# 188357  30581096  My apartment is located in  next to the Parram...
# 188391  30588358  Fully-furnished two-storey family home: 4 bdrm...
# 188416  30593866  Beautiful natural sunny apartment with spa, po...
#
#                                                     space
# 0       HOUSE : _________ * DUCTED AIR CONDITIONING IN...  \
# 47      Enjoy this fabulous Home away from home, and h...
# 76      Sunny, studio apartment . Private terrace. bus...
# 111     The House has a nighclub/home theater, pool ta...
# 138     The house is perched right on Gordons Bay with...
# ...                                                   ...
# 188296                                                NaN
# 188331                                                NaN
# 188357                                                NaN
# 188391                                                NaN
# 188416  Let's talk about the room. This room is fully ...
#
#                                               description       date
# 0       Hi! We are a married professional couple with ... 2019-02-18
# 47      Welcome to my sanctuary - a bright, comfortabl... 2019-02-01
# 76      Fully self-contained sunny studio apartment.  ... 2019-02-02
# 111     On major bus routes to City, Castle Hill, Rous... 2019-01-28
# 138     This is a fabulous contemporary villa in perfe... 2019-01-31
# ...                                                   ...        ...
# 188296  Double bedroom with en-suite bathroom in our f... 2019-02-02
# 188331  Very convenient location! Wolli Creek 50 meter... 2019-01-28
# 188357  My apartment is located in  next to the Parram... 2019-02-01
# 188391  Fully-furnished two-storey family home: 4 bdrm... 2019-01-28
# 188416  Beautiful natural sunny apartment with spa, po... 2019-02-02
#
# [6281 rows x 5 columns]

# %%
# Export filtered data
f_df.to_csv('fitered_keyword_data.csv', index=False)
